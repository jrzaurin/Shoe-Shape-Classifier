# %% [markdown]
# ## UTILITIES TO UNDERSTAND AND VISUALIZE THE CONTENT OF THE IMAGES
#
# Series of helper functions designed to capture well the points around the silhouette of the shoes in the images.

# %%
import numpy as np
import pandas as pd
import cv2
import pylab as pyl
import os
import itertools
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Let's first read the images. For this excercise, I use 5000 images of shoes of width 150.

# %%
# read 5000 shoe images
IM_DIR = "../data/shoe_images/"
images = []
for img in os.listdir(IM_DIR):
    if 'jpg' in img:
        path = os.path.join(IM_DIR, img)
        images.append(cv2.imread(path))

# %%
# all images are 150 wide
images[0].shape
# Out:
# (77, 150, 3)

# %% [markdown]
# Let's have a look

# %%
def plot_image(img):
    pyl.imshow(img)
    pyl.show()

# %%
plot_image(images[0])
plot_image(images[200])

# %% [markdown]
# The code in this repo focuses on the shape of the main item in the image. Neddless to say, the higher the resolution the better you will capture the details of that shape.
#
# Let's now define a series of functions to get a bounding box or region of interest (ROI). At this stage one might be tempted to [find contours](http://www.pyimagesearch.com/2014/04/21/building-pokedex-python-finding-game-boy-screen-step-4-6/) or use an [edge detector](http://docs.opencv.org/trunk/da/d22/tutorial_py_canny.html). However, these solutions will not work here. In the first place the background is not uniform for all images, and secondly, some of the shoe-shapes are very convoluted, and points along the outer contour may not correspond to the overall shape of the shoe. Therefore, they are not adequate to compute later the shape context matrix.

# %%
def threshold_value(img):
    """
    Returns a threshold value (0.9 or 0.98) based on whether any slice
    of the image within a central box is enterely white (white is a bitch!)
    0.9 or 0.98 come simply from a lot of experimentation.
    """

    is_color = len(img.shape) == 3
    is_grey  = len(img.shape) == 2

    if is_color:
        gray =  cv2.cvtColor(gray,cv2.COLOR_BGR2GRAY)
    elif is_grey:
        gray = img.copy()

    slices = gray.mean(axis = 1)[20:gray.shape[0]-30]
    is_white = any(x > 0.9*255 for x in slices)
    if is_white:
        return 0.98
    else:
        return 0.9

def threshold_img(img):
    """
    Simple wrap-up function for cv2.threshold()
    """

    is_color = len(img.shape) == 3
    is_grey  = len(img.shape) == 2

    t = threshold_value(img)

    if is_color:
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    elif is_grey:
        gray = img.copy()

    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    (_, thresh) = cv2.threshold(blurred, t*255, 1, cv2.THRESH_BINARY_INV)

    return thresh


def get_edges(arr, thresh):
    """
    Given an array returns the min/max where that array is less that 255*thresh
    i.e. is not white. If all the slice-array is white, returns the middle point.
    """

    if np.any(np.where(arr < thresh*255)[0]):
        e1 = min(np.where(arr < thresh*255)[0])
        e2 = max(np.where(arr < thresh*255)[0])

    else:
        e1 = len(arr)/2
        e2 = len(arr)/2

    return e1,e2


def bounding_box(img):
    """
    Returns right, left, lower and upper limits for the limiting box enclosing
    the item (shoe, dress, etc). Note that given the shapes and colors of some 
    items,finding the contours and compute the bounding box is not a viable 
    solution.
    """

    is_color = len(img.shape) == 3
    is_grey  = len(img.shape) == 2

    if is_color:
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    elif is_grey:
        gray = img.copy()

    slices = gray.mean(axis = 1)[20:gray.shape[0]-30]
    is_white = any(x > 0.9*255 for x in slices)

    if (is_white):
        h1 = min(np.apply_along_axis(get_edges, axis=0, arr=gray , thresh = 0.98)[0,:])
        h2 = max(np.apply_along_axis(get_edges, axis=0, arr=gray , thresh = 0.98)[1,:])
        w1 = min(np.apply_along_axis(get_edges, axis=1, arr=gray , thresh = 0.98)[:,0])
        w2 = max(np.apply_along_axis(get_edges, axis=1, arr=gray , thresh = 0.98)[:,1])
    else :
        h1 = min(np.apply_along_axis(get_edges, axis=0, arr=gray , thresh = 0.9)[0,:])
        h2 = max(np.apply_along_axis(get_edges, axis=0, arr=gray , thresh = 0.9)[1,:])
        w1 = min(np.apply_along_axis(get_edges, axis=1, arr=gray , thresh = 0.9)[:,0])
        w2 = max(np.apply_along_axis(get_edges, axis=1, arr=gray , thresh = 0.9)[:,1])

    return w1, w2, h1, h2

# %% [markdown]
# Let's see if the result on the images above, where all the image is ROI.

# %%
print bounding_box(images[0])
print bounding_box(images[200])
# Out:
# (0, 149, 0, 76)
# (0, 149, 0, 84)

# %% [markdown]
# Now let's find the points of interest along the shoe shape that will be later passed to the Shape Context algorithm. I am aware that the code below could be better written, but I think is good enough to illustrate what I aim for.

# %%
def shape_df(img, axis, nsteps):
    """
    Returns a data frame with the initial and end points enclosing the product
    in the image, across the x/y axis. Why a dataframe and not tuples? just for
    convenience.
    """

    is_color = len(img.shape) == 3
    is_grey  = len(img.shape) == 2

    if is_color:
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    elif is_grey:
        gray = img.copy()

    edges = bounding_box(gray)
    gray_c = gray[edges[2]:edges[3]+1, edges[0]:edges[1]+1]
    thr = threshold_value(gray_c)

    if axis == 'x' :
        cuts = np.rint(np.linspace(5, gray_c.shape[1]-1, nsteps, endpoint=True)).astype(int)

        init = np.apply_along_axis(get_edges, 0, arr = gray_c, thresh = thr)[0,:][cuts]
        end  = np.apply_along_axis(get_edges, 0, arr = gray_c, thresh = thr)[1,:][cuts]

        df = pd.DataFrame(data = {'coord' : cuts, 'init' : init, 'end' : end},
                          columns=['coord', 'init', 'end'])

    elif axis == 'y':
        cuts = np.round(np.linspace(4, gray_c.shape[0]-1, nsteps, endpoint=True)).astype(int)

        init = np.apply_along_axis(get_edges, 1, arr = gray_c, thresh = thr)[:,0][cuts]
        end  = np.apply_along_axis(get_edges, 1, arr = gray_c, thresh = thr)[:,1][cuts]

        df = pd.DataFrame(data = {'coord' : cuts, 'init' : init, 'end' : end},
                          columns=['coord', 'init', 'end'])

    return df


def shape_points(img, nsteps, mirrow=False, only_upper=False):
    """
    Simple formatting the shape_df output to be passed to the Shape Context algo
    """

    if mirrow:
        im =  cv2.flip(img, 2)
    else:
        im = img.copy()

    df_y = shape_df(im, 'y', nsteps)
    df_x = shape_df(im, 'x', nsteps)

    if (not df_y.empty) and (not df_x.empty):
        y_init = [(df_y.init[i], df_y.coord[i]) for i in xrange(df_y.shape[0])]
        y_end  = [(df_y.end[i], df_y.coord[i]) for i in xrange(df_y.shape[0])]
        x_init = [(df_x.coord[i], df_x.init[i]) for i in xrange(df_x.shape[0])]
        x_end  = [(df_x.coord[i], df_x.end[i]) for i in xrange(df_x.shape[0])]

        if only_upper: return x_init

        return y_init+y_end+x_init+x_end
    else:
        return []

# %% [markdown]
# Again, let's see what the result looks like for one of the images above

# %%
print shape_points(images[0], 30)
# Out:
# [(10, 4), (4, 6), (2, 9), (2, 11), (0, 14), (0, 16), (0, 19), (3, 21), (2, 24), (2, 26), (2, 29), (2, 31), (2, 34), (2, 36), (3, 39), (2, 41), (2, 44), (1, 46), (1, 49), (1, 51), (7, 54), (12, 56), (18, 59), (16, 61), (30, 64), (34, 66), (41, 69), (46, 71), (58, 74), (73, 76), (85, 4), (87, 6), (89, 9), (91, 11), (94, 14), (98, 16), (102, 19), (103, 21), (108, 24), (110, 26), (113, 29), (115, 31), (118, 34), (120, 36), (123, 39), (125, 41), (125, 44), (130, 46), (139, 49), (144, 51), (145, 54), (149, 56), (148, 59), (148, 61), (145, 64), (114, 66), (116, 69), (115, 71), (113, 74), (104, 76), (5, 5), (10, 4), (15, 4), (20, 6), (25, 7), (30, 0), (35, 0), (40, 2), (45, 1), (50, 0), (55, 5), (60, 9), (65, 9), (70, 6), (75, 3), (79, 2), (84, 3), (89, 9), (94, 13), (99, 17), (104, 23), (109, 26), (114, 28), (119, 35), (124, 40), (129, 46), (134, 47), (139, 48), (144, 51), (149, 55), (5, 53), (10, 55), (15, 58), (20, 61), (25, 61), (30, 64), (35, 66), (40, 68), (45, 70), (50, 72), (55, 73), (60, 74), (65, 75), (70, 75), (75, 76), (79, 76), (84, 76), (89, 76), (94, 76), (99, 76), (104, 76), (109, 75), (114, 73), (119, 64), (124, 64), (129, 65), (134, 65), (139, 65), (144, 64), (149, 60)]

# %% [markdown]
# And let's visualise it

# %%
def plot_shape(img, axis, df=None, nsteps=None):
    """
    function to overplot the shape points onto the image img
    """

    if df is not None and nsteps:
        print 'Error: provide data frame or nsteps, not both'
        return None

    if df is not None:
        edges = bounding_box(img)
        img_c = img[edges[2]:edges[3]+1, edges[0]:edges[1]+1]
        pyl.figure()
        pyl.gray()
        pyl.imshow(img_c)
        if axis == 'y':
            pyl.plot(df.init,df.coord, 'r*')
            pyl.plot(df.end, df.coord, 'r*')
            pyl.show()
        if axis == 'x':
            pyl.plot(df.coord,df.init, 'r*')
            pyl.plot(df.coord,df.end, 'r*')
            pyl.show()

    elif nsteps:
        pyl.figure()
        pyl.gray()
        pyl.imshow(img)
        if axis == 'y':
            df = shape_df(img, 'y', nsteps)
            pyl.plot(df.init,df.coord, 'r*')
            pyl.plot(df.end, df.coord, 'r*')
            pyl.show()
        if axis == 'x':
            df = shape_df(img, 'x', nsteps)
            pyl.plot(df.coord,df.init, 'r*')
            pyl.plot(df.coord,df.end, 'r*')
            pyl.show()

# %%
plot_shape(images[0], axis='x', nsteps=30)
plot_shape(images[0], axis='y', nsteps=30)

# %% [markdown]
# As you can see, in this case, there is a lot of redundancy. A lot of the points along the 'x' and 'y' axis provide the same information in terms of location around the shoe-shape. In some other cases, all points are useful.
#
# At this stage, I would like to add a caveat. As you can see, the shoe has a lot of "holes". This information is not captured by the points in the image. There are ways to add this later to the shoe-image features (and it should be done in a production-ready algorithm), but for now, we'll leave it here.
#
# In any case, now we have points accross the outer contour of the shoe. Let's see how we can use them to encode the shape of the shoe!
